# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/train-data.csv',index_col= 0)
df.head()
# Out:
#                                Name    Location  Year  ...  Seats  New_Price  Price
# 0            Maruti Wagon R LXI CNG      Mumbai  2010  ...    5.0        NaN   1.75
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015  ...    5.0        NaN  12.50
# 2                      Honda Jazz V     Chennai  2011  ...    5.0  8.61 Lakh   4.50
# 3                 Maruti Ertiga VDI     Chennai  2012  ...    7.0        NaN   6.00
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013  ...    5.0        NaN  17.74
#
# [5 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
df.shape
# Out:
# (6019, 13)

# %%
df = df.drop('New_Price',axis=1)
df.head()
# Out:
#                                Name    Location  Year  ...      Power Seats  Price
# 0            Maruti Wagon R LXI CNG      Mumbai  2010  ...  58.16 bhp   5.0   1.75
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015  ...  126.2 bhp   5.0  12.50
# 2                      Honda Jazz V     Chennai  2011  ...   88.7 bhp   5.0   4.50
# 3                 Maruti Ertiga VDI     Chennai  2012  ...  88.76 bhp   7.0   6.00
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013  ...  140.8 bhp   5.0  17.74
#
# [5 rows x 12 columns]

# %%
df = df.dropna(axis=0)

# %%
df.shape
# Out:
# (5975, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5975 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5975 non-null   object
#  1   Location           5975 non-null   object
#  2   Year               5975 non-null   int64
#  3   Kilometers_Driven  5975 non-null   int64
#  4   Fuel_Type          5975 non-null   object
#  5   Transmission       5975 non-null   object
#  6   Owner_Type         5975 non-null   object
#  7   Mileage            5975 non-null   object
#  8   Engine             5975 non-null   object
#  9   Power              5975 non-null   object
#  10  Seats              5975 non-null   float64
#  11  Price              5975 non-null   float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 606.8+ KB

# %%
df['Year'] = 2021-df['Year']

# %%
df.head()
# Out:
#                                Name    Location  Year  ...      Power Seats  Price
# 0            Maruti Wagon R LXI CNG      Mumbai    11  ...  58.16 bhp   5.0   1.75
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune     6  ...  126.2 bhp   5.0  12.50
# 2                      Honda Jazz V     Chennai    10  ...   88.7 bhp   5.0   4.50
# 3                 Maruti Ertiga VDI     Chennai     9  ...  88.76 bhp   7.0   6.00
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore     8  ...  140.8 bhp   5.0  17.74
#
# [5 rows x 12 columns]

# %%
def convert_milage(milage):
  return float(milage.split(' ')[0])

# %%
df['Mileage'] = df['Mileage'].apply(convert_milage)

# %%
df
# Out:
#                                   Name    Location  ...  Seats  Price
# 0               Maruti Wagon R LXI CNG      Mumbai  ...    5.0   1.75
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  ...    5.0  12.50
# 2                         Honda Jazz V     Chennai  ...    5.0   4.50
# 3                    Maruti Ertiga VDI     Chennai  ...    7.0   6.00
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  ...    5.0  17.74
# ...                                ...         ...  ...    ...    ...
# 6014                  Maruti Swift VDI       Delhi  ...    5.0   4.75
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  ...    5.0   4.00
# 6016             Mahindra Xylo D4 BSIV      Jaipur  ...    8.0   2.90
# 6017                Maruti Wagon R VXI     Kolkata  ...    5.0   2.65
# 6018             Chevrolet Beat Diesel   Hyderabad  ...    5.0   2.50
#
# [5975 rows x 12 columns]

# %%
def convert_engine(engine):
  return float(engine.split(' ')[0])

# %%
df['Engine']=df['Engine'].apply(convert_engine)

# %%
df
# Out:
#                                   Name    Location  ...  Seats  Price
# 0               Maruti Wagon R LXI CNG      Mumbai  ...    5.0   1.75
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  ...    5.0  12.50
# 2                         Honda Jazz V     Chennai  ...    5.0   4.50
# 3                    Maruti Ertiga VDI     Chennai  ...    7.0   6.00
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  ...    5.0  17.74
# ...                                ...         ...  ...    ...    ...
# 6014                  Maruti Swift VDI       Delhi  ...    5.0   4.75
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  ...    5.0   4.00
# 6016             Mahindra Xylo D4 BSIV      Jaipur  ...    8.0   2.90
# 6017                Maruti Wagon R VXI     Kolkata  ...    5.0   2.65
# 6018             Chevrolet Beat Diesel   Hyderabad  ...    5.0   2.50
#
# [5975 rows x 12 columns]

# %%
df['Power'] = df['Power'].str.replace('bhp','')

# %%
df
# Out:
#                                   Name    Location  Year  ...   Power Seats  Price
# 0               Maruti Wagon R LXI CNG      Mumbai    11  ...  58.16    5.0   1.75
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune     6  ...  126.2    5.0  12.50
# 2                         Honda Jazz V     Chennai    10  ...   88.7    5.0   4.50
# 3                    Maruti Ertiga VDI     Chennai     9  ...  88.76    7.0   6.00
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore     8  ...  140.8    5.0  17.74
# ...                                ...         ...   ...  ...     ...   ...    ...
# 6014                  Maruti Swift VDI       Delhi     7  ...     74    5.0   4.75
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur     6  ...     71    5.0   4.00
# 6016             Mahindra Xylo D4 BSIV      Jaipur     9  ...    112    8.0   2.90
# 6017                Maruti Wagon R VXI     Kolkata     8  ...   67.1    5.0   2.65
# ...

# %%
df = df[~(df['Power'] == 'null ')]

# %%
df
# Out:
#                                   Name    Location  Year  ...   Power Seats  Price
# 0               Maruti Wagon R LXI CNG      Mumbai    11  ...  58.16    5.0   1.75
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune     6  ...  126.2    5.0  12.50
# 2                         Honda Jazz V     Chennai    10  ...   88.7    5.0   4.50
# 3                    Maruti Ertiga VDI     Chennai     9  ...  88.76    7.0   6.00
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore     8  ...  140.8    5.0  17.74
# ...                                ...         ...   ...  ...     ...   ...    ...
# 6014                  Maruti Swift VDI       Delhi     7  ...     74    5.0   4.75
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur     6  ...     71    5.0   4.00
# 6016             Mahindra Xylo D4 BSIV      Jaipur     9  ...    112    8.0   2.90
# 6017                Maruti Wagon R VXI     Kolkata     8  ...   67.1    5.0   2.65
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5872 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5872 non-null   object
#  1   Location           5872 non-null   object
#  2   Year               5872 non-null   int64
#  3   Kilometers_Driven  5872 non-null   int64
#  4   Fuel_Type          5872 non-null   object
#  5   Transmission       5872 non-null   object
#  6   Owner_Type         5872 non-null   object
#  7   Mileage            5872 non-null   float64
#  8   Engine             5872 non-null   float64
#  9   Power              5872 non-null   object
#  10  Seats              5872 non-null   float64
#  11  Price              5872 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 596.4+ KB

# %%
df['Power']=df['Power'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5872 entries, 0 to 6018
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5872 non-null   object
#  1   Location           5872 non-null   object
#  2   Year               5872 non-null   int64
#  3   Kilometers_Driven  5872 non-null   int64
#  4   Fuel_Type          5872 non-null   object
#  5   Transmission       5872 non-null   object
#  6   Owner_Type         5872 non-null   object
#  7   Mileage            5872 non-null   float64
#  8   Engine             5872 non-null   float64
#  9   Power              5872 non-null   float64
#  10  Seats              5872 non-null   float64
#  11  Price              5872 non-null   float64
# dtypes: float64(5), int64(2), object(5)
# memory usage: 596.4+ KB

# %%
df['Fuel_Type'].unique() , df['Transmission'].unique() , df['Owner_Type'].unique()
# Out:
# (array(['CNG', 'Diesel', 'Petrol', 'LPG'], dtype=object),
#  array(['Manual', 'Automatic'], dtype=object),
#  array(['First', 'Second', 'Fourth & Above', 'Third'], dtype=object))

# %%
df_f = pd.get_dummies(df['Fuel_Type'])
df_t = pd.get_dummies(df['Transmission'])
df_o = pd.get_dummies(df['Owner_Type'])

# %%
df = pd.concat((df,df_f,df_t,df_o),axis=1)

# %%
df.head()
# Out:
#                                Name    Location  ...  Second  Third
# 0            Maruti Wagon R LXI CNG      Mumbai  ...       0      0
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  ...       0      0
# 2                      Honda Jazz V     Chennai  ...       0      0
# 3                 Maruti Ertiga VDI     Chennai  ...       0      0
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  ...       1      0
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (5872, 22)

# %%
df = df.drop(['Fuel_Type','Transmission','Owner_Type'],axis=1)

# %%
df.shape
# Out:
# (5872, 19)

# %%
df.head()
# Out:
#                                Name    Location  ...  Second  Third
# 0            Maruti Wagon R LXI CNG      Mumbai  ...       0      0
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  ...       0      0
# 2                      Honda Jazz V     Chennai  ...       0      0
# 3                 Maruti Ertiga VDI     Chennai  ...       0      0
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  ...       1      0
#
# [5 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5872 entries, 0 to 6018
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5872 non-null   object
#  1   Location           5872 non-null   object
#  2   Year               5872 non-null   int64
#  3   Kilometers_Driven  5872 non-null   int64
#  4   Mileage            5872 non-null   float64
#  5   Engine             5872 non-null   float64
#  6   Power              5872 non-null   float64
#  7   Seats              5872 non-null   float64
#  8   Price              5872 non-null   float64
#  9   CNG                5872 non-null   uint8
#  10  Diesel             5872 non-null   uint8
#  11  LPG                5872 non-null   uint8
#  12  Petrol             5872 non-null   uint8
#  13  Automatic          5872 non-null   uint8
#  14  Manual             5872 non-null   uint8
#  15  First              5872 non-null   uint8
# ...

# %%
df['Location'].unique()
# Out:
# array(['Mumbai', 'Pune', 'Chennai', 'Coimbatore', 'Hyderabad', 'Jaipur',
#        'Kochi', 'Kolkata', 'Delhi', 'Bangalore', 'Ahmedabad'],
#       dtype=object)

# %%
df['Location'].value_counts()
# Out:
# Mumbai        775
# Hyderabad     718
# Kochi         645
# Coimbatore    629
# Pune          594
# Delhi         545
# Kolkata       521
# Chennai       476
# Jaipur        402
# Bangalore     347
# Ahmedabad     220
# Name: Location, dtype: int64

# %%
df_l = pd.get_dummies(df['Location'])

# %%
df= pd.concat((df,df_l),axis=1)

# %%
df
# Out:
#                                   Name    Location  Year  ...  Kolkata  Mumbai  Pune
# 0               Maruti Wagon R LXI CNG      Mumbai    11  ...        0       1     0
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune     6  ...        0       0     1
# 2                         Honda Jazz V     Chennai    10  ...        0       0     0
# 3                    Maruti Ertiga VDI     Chennai     9  ...        0       0     0
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore     8  ...        0       0     0
# ...                                ...         ...   ...  ...      ...     ...   ...
# 6014                  Maruti Swift VDI       Delhi     7  ...        0       0     0
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur     6  ...        0       0     0
# 6016             Mahindra Xylo D4 BSIV      Jaipur     9  ...        0       0     0
# 6017                Maruti Wagon R VXI     Kolkata     8  ...        1       0     0
# ...

# %%
df.head()
# Out:
#                                Name    Location  Year  ...  Kolkata  Mumbai  Pune
# 0            Maruti Wagon R LXI CNG      Mumbai    11  ...        0       1     0
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune     6  ...        0       0     1
# 2                      Honda Jazz V     Chennai    10  ...        0       0     0
# 3                 Maruti Ertiga VDI     Chennai     9  ...        0       0     0
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore     8  ...        0       0     0
#
# [5 rows x 30 columns]

# %%
df = df.drop('Location',axis=1)

# %%
df.head(10)
# Out:
#                                   Name  Year  ...  Mumbai  Pune
# 0               Maruti Wagon R LXI CNG    11  ...       1     0
# 1     Hyundai Creta 1.6 CRDi SX Option     6  ...       0     1
# 2                         Honda Jazz V    10  ...       0     0
# 3                    Maruti Ertiga VDI     9  ...       0     0
# 4      Audi A4 New 2.0 TDI Multitronic     8  ...       0     0
# 5      Hyundai EON LPG Era Plus Option     9  ...       0     0
# 6               Nissan Micra Diesel XV     8  ...       0     0
# 7    Toyota Innova Crysta 2.8 GX AT 8S     5  ...       1     0
# 8  Volkswagen Vento Diesel Comfortline     8  ...       0     1
# 9       Tata Indica Vista Quadrajet LS     9  ...       0     0
#
# [10 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5872 entries, 0 to 6018
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5872 non-null   object
#  1   Year               5872 non-null   int64
#  2   Kilometers_Driven  5872 non-null   int64
#  3   Mileage            5872 non-null   float64
#  4   Engine             5872 non-null   float64
#  5   Power              5872 non-null   float64
#  6   Seats              5872 non-null   float64
#  7   Price              5872 non-null   float64
#  8   CNG                5872 non-null   uint8
#  9   Diesel             5872 non-null   uint8
#  10  LPG                5872 non-null   uint8
#  11  Petrol             5872 non-null   uint8
#  12  Automatic          5872 non-null   uint8
#  13  Manual             5872 non-null   uint8
#  14  First              5872 non-null   uint8
#  15  Fourth & Above     5872 non-null   uint8
# ...

# %%
len(df['Name'].unique())
# Out:
# 1811

# %%
def car_name(x):
  car = x.split(' ')[:2]
  sep = ' '
  return sep.join(car)

# %%
df['Name'] = df['Name'].apply(car_name)

# %%
len(df['Name'].unique())
# Out:
# 207

# %%
car_counts = df['Name'].value_counts()
cars_less_then_15 = car_counts[car_counts <= 15]

# %%
def filter_cars(x):
  if x in cars_less_then_15:
    return False
  else:
    return True

# %%
df = df[df['Name'].apply(filter_cars)]

# %%
df['Name'].value_counts()
# Out:
# Maruti Swift      327
# Honda City        265
# Hyundai i20       247
# Hyundai Verna     170
# Toyota Innova     164
#                  ...
# Hyundai Accent     18
# Hyundai Santa      17
# Maruti A-Star      17
# Honda Mobilio      16
# Tata Manza         16
# Name: Name, Length: 83, dtype: int64

# %%
df['Name'] = df['Name'].str.strip()
df['Name'] = df['Name'].str.lower()

# %%
df['Name']
# Out:
# 0         maruti wagon
# 1        hyundai creta
# 2           honda jazz
# 3        maruti ertiga
# 4              audi a4
#              ...
# 6014      maruti swift
# 6015     hyundai xcent
# 6016     mahindra xylo
# 6017      maruti wagon
# 6018    chevrolet beat
# Name: Name, Length: 5241, dtype: object

# %%
df_n = pd.get_dummies(df['Name'])

# %%
df = pd.concat((df,df_n),axis=1)

# %%
df.head()
# Out:
#             Name  Year  ...  volkswagen polo  volkswagen vento
# 0   maruti wagon    11  ...                0                 0
# 1  hyundai creta     6  ...                0                 0
# 2     honda jazz    10  ...                0                 0
# 3  maruti ertiga     9  ...                0                 0
# 4        audi a4     8  ...                0                 0
#
# [5 rows x 111 columns]

# %%
df['Engine'].hist()

# %%
df = df[(df['Power'] >= ((df['Power'].mean()) - 2*(df['Power'].std()))) & (df['Power'] <= ((df['Power'].mean()) + 2*(df['Power'].std())))]

# %%
df['Kilometers_Driven'].hist()

# %%
df['Power'].hist()

# %%
df = df.drop('Name',axis=1)

# %%
df.head()
# Out:
#    Year  Kilometers_Driven  ...  volkswagen polo  volkswagen vento
# 0    11              72000  ...                0                 0
# 1     6              41000  ...                0                 0
# 2    10              46000  ...                0                 0
# 3     9              87000  ...                0                 0
# 4     8              40670  ...                0                 0
#
# [5 rows x 110 columns]

# %% [markdown]
# # Creating Model

# %%
X = df.drop('Price',axis=1)
Y = df[['Price']]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X,Y,train_size=0.8)

# %%
from sklearn.linear_model import LinearRegression
lmodel = LinearRegression()

# %%
lmodel.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(ytrain,lmodel.predict(xtrain)))
print(mean_absolute_error(ytest,lmodel.predict(xtest)))
# Out:
# 1.6561464349985981
# 1.6854707381260206

# %%
ytest_pred = lmodel.predict(xtest)
np.hstack((ytest,ytest_pred))[0:20,:]
# Out:
# array([[ 5.95      ,  6.95120896],
#        [ 8.5       ,  8.32027791],
#        [ 2.65      ,  2.00616069],
#        [ 5.75      ,  5.68682416],
#        [ 1.1       , -1.6167516 ],
#        [ 4.7       ,  4.03586857],
#        [ 9.75      ,  9.55723895],
#        [ 3.53      ,  4.54803674],
#        [ 8.15      ,  8.51479924],
#        [ 5.5       ,  4.84134851],
#        [21.33      , 20.74887345],
#        [17.25      , 21.11418485],
#        [10.        , 17.94432797],
#        [ 4.        ,  3.81714913],
#        [ 4.5       ,  4.55401229],
#        [ 4.1       ,  5.70880414],
#        [ 5.1       ,  7.07766649],
#        [ 9.18      , 10.65076344],
#        [ 1.74      ,  1.86527638],
#        [ 3.5       ,  4.56732365]])

# %% [markdown]
# # Predicting the price

# %%
def predict_price(year,kms,mig,eng,pwr,seats,fuel_type,transmission,owner,city,name):

  input = np.zeros(len(xtrain.columns))

  input[0] = year
  input[1] = kms
  input[2] = mig
  input[3] = eng
  input[4] = pwr
  input[5] = seats

  idf = np.where(xtrain.columns == fuel_type)[0][0]
  idt = np.where(xtrain.columns == transmission)[0][0]
  ido = np.where(xtrain.columns == owner)[0][0]
  idc = np.where(xtrain.columns == city)[0][0]
  idd = np.where(xtrain.columns == name)[0][0]


  input[idf] = 1
  input[idt] = 1
  input[ido] = 1
  input[idc] = 1
  input[idd] = 1

  return lmodel.predict([input])[0][0]

# %%
predict_price(1,60000,14,120,89,5,'Diesel','Automatic','First','Delhi','audi a4')
# Out:
# 25.326136607114286

# %% [markdown]
# # Saving model for deployment

# %%
import pickle
with open('car_price.pickle','wb') as f:
  pickle.dump(lmodel,f)

# %%
import json
columns = {'data_columns' : [col.lower() for col in xtrain.columns]}

with open("columns.json","w") as f:
  f.write(json.dumps(columns))
